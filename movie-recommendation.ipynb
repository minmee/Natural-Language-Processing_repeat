# %%
# https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# https://drive.google.com/file/d/15Q7DZ7xrJsI2Hji-WbkU9j1mwnODBd5A/view?usp=sharing
# https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4

# %%
import urllib.request
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import re

from PIL import Image
from io import BytesIO

from nltk.tokenize import RegexpTokenizer
import nltk
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import cosine_similarity # 코사인 유사도

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (3.8.3)
# Requirement already satisfied: six>=1.5.0 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from gensim) (1.16.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from gensim) (1.9.0)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from gensim) (1.7.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from gensim) (1.20.3)
# Requirement already satisfied: requests in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from smart-open>=1.8.1->gensim) (2.26.0)
# Requirement already satisfied: boto>=2.32 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied: boto3 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from smart-open>=1.8.1->gensim) (1.20.24)
# Requirement already satisfied: bz2file in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from smart-open>=1.8.1->gensim) (0.98)
# Requirement already satisfied: botocore<1.24.0,>=1.23.24 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (1.23.24)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from botocore<1.24.0,>=1.23.24->boto3->smart-open>=1.8.1->gensim) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from botocore<1.24.0,>=1.23.24->boto3->smart-open>=1.8.1->gensim) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.0.4)

# %%
# !pip install Mecab
# Out:
# Requirement already satisfied: Mecab in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (0.996.3)

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from konlpy) (1.20.3)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from konlpy) (4.6.3)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from konlpy) (1.3.0)

# %%
df = pd.read_csv('./dataset/data.csv')
df.head()
# Out:
#    Unnamed: 0                                               Desc  \
# 0           0  We know that power is shifting: From West to E...
# 1           1  Following the success of The Accidental Billio...
# 2           2  How to tap the power of social software and ne...
# 3           3  William J. Bernstein is an American financial ...
# 4           4  Amazing book. And I joined Steve Jobs and many...
#
#    Unnamed: 0.1                author     genre  \
# 0           0.0           Moisés Naím  Business
# 1           1.0       Blake J. Harris  Business
# 2           2.0          Chris Brogan  Business
# 3           3.0  William J. Bernstein  Business
# 4           4.0           Akio Morita  Business
#
#                                           image_link  rating  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...    3.63
# 1  https://i.gr-assets.com/images/S/compressed.ph...    3.94
# 2  https://i.gr-assets.com/images/S/compressed.ph...    3.78
# 3  https://i.gr-assets.com/images/S/compressed.ph...    4.20
# 4  https://i.gr-assets.com/images/S/compressed.ph...    4.05
#
#                                                title
# 0  The End of Power: From Boardrooms to Battlefie...
# 1  Console Wars: Sega, Nintendo, and the Battle t...
# 2  Trust Agents: Using the Web to Build Influence...
# 3                      The Four Pillars of Investing
# 4                Made in Japan: Akio Morita and Sony

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2382 entries, 0 to 2381
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2382 non-null   int64
#  1   Desc          2382 non-null   object
#  2   Unnamed: 0.1  1185 non-null   float64
#  3   author        2382 non-null   object
#  4   genre         2382 non-null   object
#  5   image_link    2382 non-null   object
#  6   rating        2382 non-null   float64
#  7   title         2382 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 149.0+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1       rating
# count  2382.000000   1185.000000  2382.000000
# mean   1226.073887    596.875949     3.995223
# std     716.658518    346.103136     0.217733
# min       0.000000      0.000000     3.080000
# 25%     603.250000    296.000000     3.870000
# 50%    1208.500000    601.000000     4.000000
# 75%    1854.750000    897.000000     4.140000
# max    2450.000000   1193.000000     4.650000

# %%
import utils_parser as parser

# %%
parser.make_lower_case('Abc')
# Out:
# 'abc'

# %%
def _removeNonAscii(s):
    return "".join(i for i in s if  ord(i)<128)

def make_lower_case(text):
    return text.lower()

def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'[a-zA-Z]+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text

# %%
df['cleaned'] = df['Desc'].apply(_removeNonAscii)
df['cleaned'] = df['cleaned'].apply(make_lower_case)
df['cleaned'] = df['cleaned'].apply(remove_stop_words)
df['cleaned'] = df['cleaned'].apply(remove_punctuation)
df['cleaned'] = df['cleaned'].apply(remove_html)

# %%
df.head()

# %%
df['cleaned'].replace('', np.nan, inplace = True)

# %%
# notna() - 누락값 여부(누락값이 있으면 False)
df = df[df['cleaned'].notna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2381 entries, 0 to 2381
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2381 non-null   int64
#  1   Desc          2381 non-null   object
#  2   Unnamed: 0.1  1185 non-null   float64
#  3   author        2381 non-null   object
#  4   genre         2381 non-null   object
#  5   image_link    2381 non-null   object
#  6   rating        2381 non-null   float64
#  7   title         2381 non-null   object
#  8   cleaned       2381 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 186.0+ KB

# %%
corpus = []
for words in df['cleaned']:
    corpus.append(words.split())

# %%
corpus
# Out:
# [['know',
#   'power',
#   'shifting',
#   'west',
#   'east',
#   'north',
#   'south',
#   'presidential',
#   'palaces',
#   'public',
#   'squares',
#   'formidable',
#   'corporate',
#   'behemoths',
#   'nimble',
#   'startups',
#   'and',
#   'slowly',
#   'surely',
#   'men',
#   'women',
#   'power',
#   'merely',
#   'shifting',
#   'dispersing',
#   'also',
#   'decaying',
#   'power',
#   'today',
#   'constrained',
#   'risk',
#   'losing',
#   'ever',
#   'before',
#   'end',
#   'power',
#   'award',
#   'winning',
#   'columnist',
#   'former',
#   'foreign',
#   'policy',
#   'editor',
#   'moiss',
#   'nam',
#   'illuminates',
#   'struggle',
#   'once',
#   'dominant',
#   'megaplayers',
#   'new',
#   'micropowers',
#   'challenging',
#   'every',
#   'field',
#   'human',
#   'endeavor',
#   'drawing',
#   'provocative',
#   'original',
#   'research',
#   'nam',
#   'shows',
#   'antiestablishment',
#   'drive',
#   'micropowers',
#   'topple',
#   'tyrants',
#   'dislodge',
#   'monopolies',
#   'open',
#   'remarkable',
#   'new',
#   'opportunities',
#   'also',
#   'lead',
#   'chaos',
#   'paralysis',
#   'nam',
#   'deftly',
#   'covers',
#   'seismic',
#   'changes',
#   'underway',
#   'business',
#   'religion',
#   'education',
#   'within',
#   'families',
#   'matters',
#   'war',
#   'peace',
#   'examples',
#   'abound',
#   'walks',
#   'life',
#   'eighty',
#   'nine',
#   'countries',
#   'ruled',
#   'autocrats',
#   'today',
#   'half',
#   'world',
#   's',
#   'population',
#   'lives',
#   'democracies',
#   'ceo',
#   's',
#   'constrained',
#   'shorter',
#   'tenures',
#   'predecessors',
#   'modern',
#   'tools',
#   'war',
#   'cheaper',
#   'accessible',
#   'make',
#   'possible',
#   'groups',
#   'like',
#   'hezbollah',
#   'afford',
#   'drones',
#   'second',
#   'half',
#   'top',
#   'ten',
#   'hedge',
#   'funds',
#   'earned',
#   'world',
#   's',
#   'largest',
#   'six',
#   'banks',
#   'combined',
#   'power',
#   'retain',
#   'erecting',
#   'powerful',
#   'barriers',
#   'keep',
#   'challengers',
#   'bay',
#   'today',
#   'insurgent',
#   'forces',
#   'dismantle',
#   'barriers',
#   'quickly',
#   'easily',
#   'ever',
#   'find',
#   'become',
#   'vulnerable',
#   'process',
#   'accessible',
#   'captivating',
#   'nam',
#   'offers',
#   'revolutionary',
#   'look',
#   'inevitable',
#   'end',
#   'powerand',
#   'change',
#   'world'],
#  ['following',
#   'success',
#   'accidental',
#   'billionaires',
#   'moneyball',
#   'comes',
#   'console',
#   'warsa',
#   'mesmerizing',
#   'behind',
#   'the',
#   'scenes',
#   'business',
#   'thriller',
#   'chronicles',
#   'sega',
#   'small',
#   'scrappy',
#   'gaming',
#   'company',
#   'led',
#   'unlikely',
#   'visionary',
#   'team',
#   'rebels',
#   'took',
#   'juggernaut',
#   'nintendo',
#   'revolutionized',
#   'video',
#   'game',
#   'industry',
#   'in',
#   'nintendo',
#   'virtual',
#   'monopoly',
#   'video',
#   'game',
#   'industry',
#   'sega',
#   'hand',
#   'faltering',
#   'arcade',
#   'company',
#   'big',
#   'aspirations',
#   'even',
#   'bigger',
#   'personalities',
#   'would',
#   'change',
#   'arrival',
#   'tom',
#   'kalinske',
#   'man',
#   'knew',
#   'nothing',
#   'videogames',
#   'everything',
#   'fighting',
#   'uphill',
#   'battles',
#   'unconventional',
#   'tactics',
#   'combined',
#   'blood',
#   'sweat',
#   'bold',
#   'ideas',
#   'renegade',
#   'employees',
#   'transformed',
#   'sega',
#   'eventually',
#   'led',
#   'ruthless',
#   'david',
#   'and',
#   'goliath',
#   'showdown',
#   'rival',
#   'nintendo',
#   'the',
#   'battle',
#   'vicious',
#   'relentless',
#   'highly',
#   'profitable',
#   'eventually',
#   'sparking',
#   'global',
#   'corporate',
#   'war',
#   'would',
#   'fought',
#   'several',
#   'fronts',
#   'living',
#   'rooms',
#   'schoolyards',
#   'boardrooms',
#   'congress',
#   'once',
#   'in',
#   'a',
#   'lifetime',
#   'no',
#   'holds',
#   'barred',
#   'conflict',
#   'pitted',
#   'brother',
#   'brother',
#   'kid',
#   'adult',
#   'sonic',
#   'mario',
#   'us',
#   'japan',
#   'based',
#   'two',
#   'hundred',
#   'interviews',
#   'former',
#   'sega',
#   'nintendo',
#   'employees',
#   'console',
#   'wars',
#   'underdog',
#   'tale',
#   'kalinske',
#   'miraculously',
#   'turned',
#   'industry',
#   'punchline',
#   'market',
#   'leader',
#   'story',
#   'humble',
#   'family',
#   'man',
#   'extraordinary',
#   'imagination',
#   'gift',
#   'turning',
#   'problems',
#   'competitive',
#   'advantages',
#   'inspired',
#   'team',
#   'underdogs',
#   'slay',
#   'giant',
#   'and',
#   'result',
#   'birth',
#   'billion',
#   'dollar',
#   'industry'],
#  ['tap',
#   'power',
#   'social',
#   'software',
#   'networks',
#   'build',
#   'business',
#   'trust',
#   'agents',
#   'two',
#   'social',
#   'media',
#   'veterans',
#   'show',
#   'tap',
#   'power',
#   'social',
#   'networks',
#   'build',
#   'brand',
#   's',
#   'influence',
#   'reputation',
#   'and',
#   'course',
#   'profits',
#   'today',
#   's',
#   'online',
#   'influencers',
#   'web',
#   'natives',
#   'trade',
#   'trust',
#   'reputation',
#   'relationships',
#   'using',
#   'social',
#   'media',
#   'accrue',
#   'influence',
#   'builds',
#   'brings',
#   'businesses',
#   'online',
#   'the',
#   'book',
#   'shows',
#   'people',
#   'use',
#   'online',
#   'social',
#   'tools',
#   'build',
#   'networks',
#   'influence',
#   'use',
#   'networks',
#   'positively',
#   'impact',
#   'business',
#   'trust',
#   'key',
#   'building',
#   'online',
#   'reputations',
#   'traffic',
#   'trust',
#   'agents',
#   'key',
#   'people',
#   'business',
#   'needs',
#   'side',
#   'delivers',
#   'actionable',
#   'steps',
#   'case',
#   'studies',
#   'show',
#   'social',
#   'media',
#   'positively',
#   'impact',
#   'business',
#   'written',
#   'authors',
#   'ten',
#   'years',
#   'online',
#   'media',
#   'experience',
#   'shows',
#   'build',
#   'wield',
#   'influence',
#   'online',
#   'benefit',
#   'brand',
#   'combines',
#   'high',
#   'level',
#   'theory',
#   'practical',
#   'step',
#   'by',
#   'step',
#   'guidance',
#   'want',
#   'business',
#   'succeed',
#   'sit',
#   'sidelines',
#   'instead',
#   'use',
#   'web',
#   'build',
#   'trust',
#   'consumers',
#   'using',
#   'trust',
#   'agents'],
#  ['william',
#   'j',
#   'bernstein',
#   'american',
#   'financial',
#   'theorist',
#   'neurologist',
#   'research',
#   'field',
#   'modern',
#   'portfolio',
#   'theory',
#   'published',
#   'books',
#   'individual',
#   'investors',
#   'wish',
#   'manage',
#   'equity',
#   'portfolios',
#   'lives',
#   'portland',
#   'oregon'],
#  ['amazing',
#   'book',
#   'joined',
#   'steve',
#   'jobs',
#   'many',
#   'akio',
#   'morita',
#   'fan',
#   'club',
#   'did',
#   'know',
#   'sensation',
#   'steve',
#   'jobs',
#   'wanted',
#   'build',
#   'apple',
#   'like',
#   'sony',
#   'similarities',
#   'apple',
#   'sony',
#   'reputation',
#   'creating',
#   'perfectly',
#   'crafted',
#   'consumer',
#   'products',
#   'conquer',
#   'marketplace',
#   'apple',
#   'still',
#   'does',
#   'fact',
#   'both',
#   'companies',
#   'leaders',
#   'personal',
#   'technology',
#   'apple',
#   'drew',
#   'inspiration',
#   'sony',
#   's',
#   'walkman',
#   'inspiration',
#   'culminated'],
#  ['tradition',
#   'phil',
#   'knight',
#   's',
#   'shoe',
#   'dog',
#   'comes',
#   'incredible',
#   'untold',
#   'story',
#   'netflix',
#   'went',
#   'concept',
#   'company',
#   'all',
#   'revealed',
#   'co',
#   'founder',
#   'first',
#   'ceo',
#   'marc',
#   'randolph',
#   'upon',
#   'time',
#   'brick',
#   'and',
#   'mortar',
#   'video',
#   'stores',
#   'king',
#   'late',
#   'fees',
#   'ubiquitous',
#   'video',
#   'streaming',
#   'unheard',
#   'of',
#   'widespread',
#   'dvd',
#   'adoption',
#   'seemed',
#   'imminent',
#   'flying',
#   'cars',
#   'indeed',
#   'widely',
#   'accepted',
#   'laws',
#   'land',
#   'marc',
#   'randolph',
#   'idea',
#   'simple',
#   'thought',
#   'leveraging',
#   'internet',
#   'rent',
#   'movies',
#   'and',
#   'one',
#   'many',
#   'far',
#   'worse',
#   'proposals',
#   'like',
#   'personalized',
#   'baseball',
#   'bats',
#   'shampoo',
#   'delivery',
#   'service',
#   'randolph',
#   'would',
#   'pitch',
#   'business',
#   'partner',
#   'reed',
#   'hastings',
#   'commute',
#   'work',
#   'morning',
#   'hastings',
#   'intrigued',
#   'pair',
#   'with',
#   'hastings',
#   'primary',
#   'investor',
#   'randolph',
#   'ceo',
#   'founded',
#   'company',
#   'million',
#   'subscribers',
#   'netflix',
#   's',
#   'triumph',
#   'feels',
#   'inevitable',
#   'twenty',
#   'first',
#   'century',
#   's',
#   'disruptive',
#   'start',
#   'began',
#   'believers',
#   'calamity',
#   'every',
#   'turn',
#   'pitch',
#   'mother',
#   'early',
#   'investor',
#   'motel',
#   'conference',
#   'room',
#   'served',
#   'first',
#   'office',
#   'server',
#   'crashes',
#   'launch',
#   'day',
#   'now',
#   'infamous',
#   'meeting',
#   'netflix',
#   'brass',
#   'pitched',
#   'blockbuster',
#   'acquire',
#   'them',
#   'marc',
#   'randolph',
#   's',
#   'transformational',
#   'journey',
#   'exemplifies',
#   'anyone',
#   'grit',
#   'gut',
#   'instincts',
#   'determination',
#   'change',
#   'world',
#   'even',
#   'idea',
#   'many',
#   'think',
#   'never',
#   'work',
#   'emerges',
#   'though',
#   'inside',
#   'story',
#   'one',
#   'world',
#   's',
#   'iconic',
#   'companies',
#   'full',
#   'counter',
#   'intuitive',
#   'concepts',
#   'written',
#   'binge',
#   'worthy',
#   'prose',
#   'answers',
#   'fundamental',
#   'questions',
#   'taking',
#   'leap',
#   'faith',
#   'business',
#   'life',
#   'begin',
#   'weather',
#   'disappointment',
#   'failure',
#   'deal',
#   'success',
#   'even',
#   'success',
#   'idea',
#   'generation',
#   'team',
#   'building',
#   'knowing',
#   'time',
#   'let',
#   'go',
#   'never',
#   'work',
#   'ultimate',
#   'follow',
#   'your',
#   'dreams',
#   'parable',
#   'also',
#   'one',
#   'dramatic',
#   'insightful',
#   'entrepreneurial',
#   'stories',
#   'time'],
#  ['gregory',
#   'zuckerman',
#   'bestselling',
#   'author',
#   'greatest',
#   'trade',
#   'ever',
#   'frackers',
#   'answers',
#   'question',
#   'investors',
#   'asking',
#   'decades',
#   'jim',
#   'simons',
#   'it',
#   'shortlisted',
#   'financial',
#   'times',
#   'mckinsey',
#   'business',
#   'book',
#   'year',
#   'awardjim',
#   'simons',
#   'greatest',
#   'money',
#   'maker',
#   'modern',
#   'financial',
#   'history',
#   'investor',
#   'warren',
#   'buffett',
#   'peter',
#   'lynch',
#   'ray',
#   'dalio',
#   'steve',
#   'cohen',
#   'george',
#   'soros',
#   'can',
#   'touch',
#   'record',
#   'since',
#   'renaissance',
#   's',
#   'signature',
#   'medallion',
#   'fund',
#   'generated',
#   'average',
#   'annual',
#   'returns',
#   'percent',
#   'firm',
#   'earned',
#   'profits',
#   'billion',
#   'simons',
#   'worth',
#   'twenty',
#   'three',
#   'billion',
#   'dollars',
#   'drawing',
#   'unprecedented',
#   'access',
#   'simons',
#   'dozens',
#   'current',
#   'former',
#   'employees',
#   'zuckerman',
#   'veteran',
#   'wall',
#   'street',
#   'journal',
#   'investigative',
#   'reporter',
#   'tells',
#   'gripping',
#   'story',
#   'world',
#   'class',
#   'mathematician',
#   'former',
#   'code',
#   'breaker',
#   'mastered',
#   'market',
#   'simons',
#   'pioneered',
#   'data',
#   'driven',
#   'algorithmic',
#   'approach',
#   'that',
#   's',
#   'sweeping',
#   'world',
#   'as',
#   'renaissance',
#   'became',
#   'market',
#   'force',
#   'executives',
#   'began',
#   'influencing',
#   'world',
#   'beyond',
#   'finance',
#   'simons',
#   'became',
#   'major',
#   'figure',
#   'scientific',
#   'research',
#   'education',
#   'liberal',
#   'politics',
#   'senior',
#   'executive',
#   'robert',
#   'mercer',
#   'responsible',
#   'anyone',
#   'else',
#   'trump',
#   'presidency',
#   'placing',
#   'steve',
#   'bannon',
#   'campaign',
#   'funding',
#   'trump',
#   's',
#   'victorious',
#   'effort',
#   'mercer',
#   'also',
#   'impacted',
#   'campaign',
#   'behind',
#   'brexit',
#   'the',
#   'man',
#   'solved',
#   'market',
#   'portrait',
#   'modern',
#   'day',
#   'midas',
#   'remade',
#   'markets',
#   'image',
#   'failed',
#   'anticipate',
#   'success',
#   'would',
#   'impact',
#   'firm',
#   'country',
#   'also',
#   'story',
#   'simons',
#   's',
#   'revolution',
#   'means',
#   'rest',
#   'us'],
#  ['bestselling',
#   'writer',
#   'david',
#   'graeber',
#   'powerful',
#   'argument',
#   'rise',
#   'meaningless',
#   'unfulfilling',
#   'jobs',
#   'consequences',
#   'does',
#   'job',
#   'make',
#   'meaningful',
#   'contribution',
#   'world',
#   'spring',
#   'david',
#   'graeber',
#   'asked',
#   'question',
#   'playful',
#   'provocative',
#   'essay',
#   'titled',
#   'phenomenon',
#   'bullshit',
#   'jobs',
#   'went',
#   'viral',
#   'million',
#   'online',
#   'views',
#   'seventeen',
#   'different',
#   'languages',
#   'people',
#   'world',
#   'still',
#   'debating',
#   'answer',
#   'millions',
#   'peoplehr',
#   'consultants',
#   'communication',
#   'coordinators',
#   'telemarketing',
#   'researchers',
#   'corporate',
#   'lawyerswhose',
#   'jobs',
#   'useless',
#   'and',
#   'tragically',
#   'know',
#   'it',
#   'people',
#   'caught',
#   'bullshit',
#   'jobs',
#   'graeber',
#   'explores',
#   'one',
#   'societys',
#   'vexing',
#   'deeply',
#   'felt',
#   'concerns',
#   'indicting',
#   'among',
#   'villains',
#   'particular',
#   'strain',
#   'finance',
#   'capitalism',
#   'betrays',
#   'ideals',
#   'shared',
#   'thinkers',
#   'ranging',
#   'keynes',
#   'lincoln',
#   'bullshit',
#   'jobs',
#   'gives',
#   'individuals',
#   'corporations',
#   'societies',
#   'permission',
#   'undergo',
#   'shift',
#   'values',
#   'placing',
#   'creative',
#   'caring',
#   'work',
#   'center',
#   'culture',
#   'book',
#   'everyone',
#   'wants',
#   'turn',
#   'vocation',
#   'back',
#   'avocation'],
#  ['aspire',
#   'lead',
#   'greater',
#   'impact',
#   'problem',
#   'youre',
#   'busy',
#   'executing',
#   'todays',
#   'demands',
#   'know',
#   'carve',
#   'time',
#   'day',
#   'job',
#   'build',
#   'leadership',
#   'skills',
#   'easy',
#   'let',
#   'immediate',
#   'problems',
#   'old',
#   'mind',
#   'sets',
#   'get',
#   'way',
#   'herminia',
#   'ibarraan',
#   'expert',
#   'professional',
#   'leadership',
#   'development',
#   'renowned',
#   'professor',
#   'insead',
#   'leading',
#   'international',
#   'business',
#   'schoolshows',
#   'managers',
#   'executives',
#   'levels',
#   'step',
#   'leadership',
#   'making',
#   'small',
#   'crucial',
#   'changes',
#   'jobs',
#   'networks',
#   'themselves',
#   'act',
#   'like',
#   'leader',
#   'think',
#   'like',
#   'leader',
#   'offers',
#   'advice',
#   'help',
#   'you',
#   'redefine',
#   'job',
#   'order',
#   'make',
#   'strategic',
#   'contributions',
#   'diversify',
#   'network',
#   'connect',
#   'to',
#   'learn',
#   'from',
#   'bigger',
#   'range',
#   'stakeholders',
#   'become',
#   'playful',
#   'self',
#   'concept',
#   'allowing',
#   'familiarand',
#   'possibly',
#   'outdatedleadership',
#   'style',
#   'evolveibarra',
#   'turns',
#   'usual',
#   'think',
#   'first',
#   'act',
#   'philosophy',
#   'head',
#   'arguing',
#   'three',
#   'things',
#   'help',
#   'learn',
#   'action',
#   'increase',
#   'calls',
#   'outsightthe',
#   'valuable',
#   'external',
#   'perspective',
#   'gain',
#   'direct',
#   'experiences',
#   'experimentation',
#   'opposed',
#   'insight',
#   'outsight',
#   'help',
#   'change',
#   'way',
#   'think',
#   'leader',
#   'kind',
#   'work',
#   'important',
#   'invest',
#   'time',
#   'relationships',
#   'matter',
#   'informing',
#   'supporting',
#   'leadership',
#   'and',
#   'ultimately',
#   'want',
#   'become',
#   'packed',
#   'self',
#   'assessments',
#   'practical',
#   'advice',
#   'help',
#   'define',
#   'pressing',
#   'leadership',
#   'challenges',
#   'book',
#   'help',
#   'devise',
#   'plan',
#   'action',
#   'become',
#   'better',
#   'leader',
#   'move',
#   'career',
#   'next',
#   'level',
#   'time',
#   'learn',
#   'doing'],
#  ['entrepreneurs',
#   'often',
#   'suffer',
#   'superhero',
#   'syndromethe',
#   'misconception',
#   'successful',
#   'must',
#   'everything',
#   'themselves',
#   'boss',
#   'also',
#   'salesperson',
#   'hr',
#   'manager',
#   'copywriter',
#   'operations',
#   'manager',
#   'online',
#   'marketing',
#   'guru',
#   'much',
#   'more',
#   'wonder',
#   'many',
#   'people',
#   'give',
#   'dream',
#   'starting',
#   'businessits',
#   'much',
#   'one',
#   'person',
#   'handle',
#   'but',
#   'outsourcing',
#   'expert',
#   'virtual',
#   'ceo',
#   'chris',
#   'ducker',
#   'knows',
#   'get',
#   'help',
#   'need',
#   'resources',
#   'afford',
#   'small',
#   'business',
#   'owners',
#   'consultants',
#   'online',
#   'entrepreneurs',
#   'dont',
#   'go',
#   'alone',
#   'discover',
#   'power',
#   'building',
#   'teams',
#   'virtual',
#   'employees',
#   'help',
#   'run',
#   'support',
#   'grow',
#   'businesses',
#   'virtual',
#   'freedom',
#   'work',
#   'virtual',
#   'staff',
#   'buy',
#   'time',
#   'become',
#   'productive',
#   'build',
#   'dream',
#   'business',
#   'step',
#   'by',
#   'step',
#   'guide',
#   'every',
#   'entrepreneur',
#   'needs',
#   'build',
#   'business',
#   'asset',
#   'working',
#   'virtual',
#   'employees',
#   'focusing',
#   'business',
#   'growth',
#   'ducker',
#   'explains',
#   'every',
#   'detail',
#   'need',
#   'grasp',
#   'figuring',
#   'jobs',
#   'outsource',
#   'finding',
#   'hiring',
#   'training',
#   'motivating',
#   'managing',
#   'virtual',
#   'assistants',
#   'with',
#   'additional',
#   'tactics',
#   'online',
#   'resources',
#   'virtual',
#   'freedom',
#   'ultimate',
#   'resource',
#   'knowledge',
#   'tools',
#   'necessary',
#   'building',
#   'dream',
#   'business',
#   'help',
#   'virtual',
#   'staff'],
#  ['new',
#   'competitive',
#   'realities',
#   'ruptured',
#   'industry',
#   'boundaries',
#   'overthrown',
#   'much',
#   'standard',
#   'management',
#   'practice',
#   'rendered',
#   'conventional',
#   'models',
#   'strategy',
#   'growth',
#   'obsolete',
#   'stead',
#   'come',
#   'powerful',
#   'ideas',
#   'methodologies',
#   'gary',
#   'hamel',
#   'c',
#   'k',
#   'prahalad',
#   'whose',
#   'much',
#   'revered',
#   'thinking',
#   'already',
#   'engendered',
#   'new',
#   'language',
#   'strategy',
#   'book',
#   'develop',
#   'coherent',
#   'model',
#   'today',
#   's',
#   'executives',
#   'identify',
#   'accomplish',
#   'less',
#   'heroic',
#   'goals',
#   'tomorrow',
#   's',
#   'marketplace',
#   'masterful',
#   'blueprint',
#   'addresses',
#   'executives',
#   'ease',
#   'tension',
#   'competing',
#   'today',
#   'clearing',
#   'path',
#   'toward',
#   'leadership',
#   'future'],
#  ['harvard',
#   'dropout',
#   'founded',
#   'microsoft',
#   'based',
#   'vision',
#   'personal',
#   'computer',
#   'every',
#   'home',
#   'every',
#   'desk',
#   'offers',
#   'clearly',
#   'written',
#   'accessible',
#   'book',
#   'describes',
#   'tools',
#   'future',
#   'change',
#   'way',
#   'make',
#   'choices',
#   'everything',
#   'buy',
#   'choose',
#   'friends',
#   'protect',
#   'families',
#   'increasingly',
#   'complicated',
#   'world',
#   'includes',
#   'compact',
#   'disc',
#   'playable',
#   'cd',
#   'rom',
#   'audio',
#   'cd',
#   'players'],
#  ['professor',
#   'kotler',
#   's',
#   'book',
#   'marketing',
#   'management',
#   'world',
#   's',
#   'widely',
#   'used',
#   'graduate',
#   'level',
#   'textbook',
#   'marketing',
#   'textbooks',
#   'include',
#   'principles',
#   'marketing',
#   'management',
#   'introduction',
#   'also',
#   'widely',
#   'used',
#   'around',
#   'world',
#   'kotler',
#   'developed',
#   'new',
#   'concepts',
#   'marketing',
#   'including',
#   'atmospherics',
#   'demarketing',
#   'megamarketing',
#   'turbomarketing',
#   'synchromarketing',
#   'believes'],
#  ['majorly',
#   'expanded',
#   'new',
#   'material',
#   'cryptoassets',
#   'icos',
#   'smart',
#   'contracts',
#   'digital',
#   'identity',
#   'definitive',
#   'book',
#   'technology',
#   'behind',
#   'bitcoin',
#   'cryptocurrency',
#   'changing',
#   'world',
#   'blockchain',
#   'ingeniously',
#   'simple',
#   'technology',
#   'powers',
#   'bitcoin',
#   'much',
#   'that',
#   'too',
#   'public',
#   'ledger',
#   'everyone',
#   'access',
#   'single',
#   'person',
#   'controls',
#   'allows',
#   'companies',
#   'individuals',
#   'collaborate',
#   'unprecedented',
#   'degree',
#   'trust',
#   'transparency',
#   'cryptographically',
#   'secure',
#   'fundamentally',
#   'open',
#   'soon',
#   'everywhere',
#   'in',
#   'blockchain',
#   'revolution',
#   'alex',
#   'tapscott',
#   'reveal',
#   'game',
#   'changing',
#   'technology',
#   'shape',
#   'future',
#   'world',
#   'economy',
#   'dramatically',
#   'improving',
#   'everything',
#   'healthcare',
#   'records',
#   'online',
#   'voting',
#   'insurance',
#   'claims',
#   'artist',
#   'royalty',
#   'payments',
#   'brilliantly',
#   'researched',
#   'highly',
#   'accessible',
#   'essential',
#   'text',
#   'next',
#   'major',
#   'paradigm',
#   'shift',
#   'read',
#   'it',
#   'left',
#   'behind'],
#  ['note',
#   'decision',
#   'made',
#   'consolidate',
#   'disney',
#   'publications',
#   'name',
#   'walt',
#   'disney',
#   'company',
#   'profile',
#   'walt',
#   'disney',
#   'characters',
#   'created',
#   'company',
#   'founded',
#   'questions',
#   'please',
#   'ask',
#   'librarian',
#   's',
#   'group',
#   'walter',
#   'elias',
#   'walt',
#   'disney',
#   'december',
#   'december',
#   'american',
#   'film',
#   'producer',
#   'director',
#   'screenwriter',
#   'voice',
#   'actor',
#   'animator',
#   'entrepreneur'],
#  ['steven',
#   'david',
#   'steve',
#   'levitt',
#   'prominent',
#   'american',
#   'economist',
#   'best',
#   'known',
#   'work',
#   'crime',
#   'particular',
#   'link',
#   'legalized',
#   'abortion',
#   'crime',
#   'rates',
#   'winner',
#   'john',
#   'bates',
#   'clark',
#   'medal',
#   'currently',
#   'alvin',
#   'h',
#   'baum',
#   'professor',
#   'economics',
#   'university',
#   'chicago',
#   'director',
#   'becker',
#   'center',
#   'chicago',
#   'price',
#   'theory',
#   'university',
#   'chicago',
#   'graduate',
#   'school',
#   'business',
#   'co',
#   'editor',
#   'journal',
#   'political',
#   'economy',
#   'published',
#   'university',
#   'chicago',
#   'press',
#   'one',
#   'well',
#   'known',
#   'economists',
#   'amongst',
#   'laymen',
#   'co',
#   'authored',
#   'best',
#   'selling',
#   'book',
#   'freakonomics',
#   'levitt',
#   'chosen',
#   'one',
#   'time',
#   'magazine',
#   's',
#   'people',
#   'shape',
#   'world',
#   'wikipedia'],
#  ['imagine',
#   'able',
#   'make',
#   'much',
#   'money',
#   'early',
#   'age',
#   'could',
#   'decide',
#   'retire',
#   'knowing',
#   'full',
#   'well',
#   'enough',
#   'money',
#   'stashed',
#   'away',
#   'ensure',
#   'life',
#   'burdened',
#   'financial',
#   'restraints',
#   'book',
#   'financial',
#   'guru',
#   'robert',
#   'kiyosaki',
#   'provides',
#   'practical',
#   'insight',
#   'put',
#   'together',
#   'financial',
#   'plan',
#   'promises',
#   'make',
#   'prosperous',
#   'allow',
#   'map',
#   'freedom',
#   'choose',
#   'retirement',
#   'age',
#   'built',
#   'upon',
#   'kiyosaki',
#   's',
#   'personal',
#   'experiences',
#   'retired',
#   'age',
#   'shows',
#   'take',
#   'advantage',
#   'smart',
#   'investments',
#   'real',
#   'estate',
#   'stock',
#   'market',
#   'help',
#   'control',
#   'financial',
#   'destiny'],
#  ['life',
#   'getting',
#   'betterand',
#   'accelerating',
#   'rate',
#   'food',
#   'availability',
#   'income',
#   'life',
#   'span',
#   'up',
#   'disease',
#   'child',
#   'mortality',
#   'violence',
#   'across',
#   'globe',
#   'though',
#   'world',
#   'far',
#   'perfect',
#   'necessities',
#   'luxuries',
#   'alike',
#   'getting',
#   'cheaper',
#   'population',
#   'growth',
#   'slowing',
#   'africa',
#   'following',
#   'asia',
#   'poverty',
#   'internet',
#   'mobile',
#   'phone',
#   'container',
#   'shipping',
#   'enriching',
#   'peoples',
#   'lives',
#   'never',
#   'before',
#   'pessimists',
#   'dominate',
#   'public',
#   'discourse',
#   'insist',
#   'soon',
#   'reach',
#   'turning',
#   'point',
#   'things',
#   'start',
#   'get',
#   'worse',
#   'saying',
#   'two',
#   'hundred',
#   'years',
#   'yet',
#   'matt',
#   'ridley',
#   'describe',
#   'things',
#   'getting',
#   'better',
#   'explains',
#   'why',
#   'prosperity',
#   'comes',
#   'everybody',
#   'working',
#   'everybody',
#   'else',
#   'habit',
#   'exchange',
#   'specializationwhich',
#   'started',
#   'years',
#   'agohas',
#   'created',
#   'collective',
#   'brain',
#   'sets',
#   'human',
#   'living',
#   'standards',
#   'rising',
#   'trend',
#   'mutual',
#   'dependence',
#   'trust',
#   'sharing',
#   'result',
#   'causes',
#   'hope',
#   'despair',
#   'this',
#   'bold',
#   'book',
#   'covers',
#   'entire',
#   'sweep',
#   'human',
#   'history',
#   'stone',
#   'age',
#   'internet',
#   'stagnation',
#   'ming',
#   'empire',
#   'invention',
#   'steam',
#   'engine',
#   'population',
#   'explosion',
#   'likely',
#   'consequences',
#   'climate',
#   'change',
#   'ends',
#   'confident',
#   'assertion',
#   'thanks',
#   'ceaseless',
#   'capacity',
#   'human',
#   'race',
#   'innovative',
#   'change',
#   'despite',
#   'inevitable',
#   'disasters',
#   'along',
#   'way',
#   'twenty',
#   'first',
#   'century',
#   'see',
#   'human',
#   'prosperity',
#   'natural',
#   'biodiversity',
#   'enhanced',
#   'acute',
#   'refreshing',
#   'revelatory',
#   'rational',
#   'optimist',
#   'change',
#   'way',
#   'thinking',
#   'world',
#   'better'],
#  ['based',
#   'years',
#   'experience',
#   'years',
#   'research',
#   'book',
#   'presents',
#   'practical',
#   'proven',
#   'strategy',
#   'creating',
#   'meeting',
#   'goals',
#   'used',
#   'million',
#   'people',
#   'achieve',
#   'extraordinary',
#   'things',
#   'life',
#   'author',
#   'brian',
#   'tracy',
#   'explains',
#   'seven',
#   'key',
#   'elements',
#   'goal',
#   'setting',
#   'steps',
#   'necessary',
#   'set',
#   'accomplish',
#   'goals',
#   'size',
#   'using',
#   'simple',
#   'language',
#   'real',
#   'life',
#   'examples',
#   'tracy',
#   'shows',
#   'crucial',
#   'work',
#   'determining',
#   'one',
#   's',
#   'strengths',
#   'values',
#   'true',
#   'goals',
#   'explains',
#   'build',
#   'self',
#   'esteem',
#   'confidence',
#   'necessary',
#   'achievement',
#   'overpower',
#   'every',
#   'problem',
#   'obstacle',
#   'overcome',
#   'difficulties',
#   'respond',
#   'challenges',
#   'continue',
#   'moving',
#   'forward',
#   'matter',
#   'happens',
#   'book',
#   's',
#   'mental',
#   'fitness',
#   'program',
#   'character',
#   'development',
#   'shows',
#   'readers',
#   'become',
#   'kind',
#   'person',
#   'inside',
#   'achieve',
#   'goal',
#   'outside'],
#  ['says',
#   'that',
#   's',
#   'best',
#   'offer',
#   'it',
#   'she',
#   'says',
#   'agrees',
#   'she',
#   'the',
#   'interview',
#   'went',
#   'greator',
#   'it',
#   'he',
#   'said',
#   'he',
#   'd',
#   'never',
#   'again',
#   'did',
#   'read',
#   'book',
#   'send',
#   'nonverbal',
#   'intelligence',
#   'soaring',
#   'joe',
#   'navarro',
#   'former',
#   'fbi',
#   'counterintelligence',
#   'officer',
#   'recognized',
#   'expert',
#   'nonverbal',
#   'behavior',
#   'explains',
#   'speed',
#   'read',
#   'people',
#   'decode',
#   'sentiments',
#   'behaviors',
#   'avoid',
#   'hidden',
#   'pitfalls',
#   'look',
#   'deceptive',
#   'behaviors',
#   'also',
#   'learn',
#   'body',
#   'language',
#   'influence',
#   'boss',
#   'family',
#   'friends',
#   'strangers',
#   'think',
#   'you',
#   'discover',
#   'the',
#   'ancient',
#   'survival',
#   'instincts',
#   'drive',
#   'body',
#   'languagewhy',
#   'face',
#   'least',
#   'likely',
#   'place',
#   'gauge',
#   'person',
#   's',
#   'true',
#   'feelingswhat',
#   'thumbs',
#   'feet',
#   'eyelids',
#   'reveal',
#   'moods',
#   'motivesthe',
#   'powerful',
#   'behaviors',
#   'reveal',
#   'confidence',
#   'true',
#   'sentimentssimple',
#   'nonverbals',
#   'instantly',
#   'establish',
#   'trustsimple',
#   'nonverbals',
#   'instantly',
#   'communicate',
#   'authorityfilled',
#   'examples',
#   'navarro',
#   's',
#   'professional',
#   'experience',
#   'definitive',
#   'book',
#   'offers',
#   'powerful',
#   'new',
#   'way',
#   'navigate',
#   'world'],
#  ['ken',
#   'blanchard',
#   'one',
#   'influential',
#   'leadership',
#   'experts',
#   'world',
#   'coauthor',
#   'iconic',
#   'bestseller',
#   'one',
#   'minute',
#   'manager',
#   'books',
#   'whose',
#   'combined',
#   'sales',
#   'total',
#   'million',
#   'copies',
#   'groundbreaking',
#   'works',
#   'translated',
#   'languages',
#   'inducted',
#   'amazons',
#   'hall',
#   'fame',
#   'one',
#   'top',
#   'bestselling',
#   'authors',
#   'time'],
#  ['bestselling',
#   'first',
#   'book',
#   'getting',
#   'things',
#   'done',
#   'veteran',
#   'coach',
#   'management',
#   'consultant',
#   'david',
#   'allen',
#   'presented',
#   'breakthrough',
#   'methods',
#   'increase',
#   'efficiency',
#   'the',
#   'personal',
#   'productivity',
#   'guru',
#   'fast',
#   'company',
#   'shows',
#   'readers',
#   'increase',
#   'ability',
#   'work',
#   'better',
#   'harder',
#   'every',
#   'day',
#   'based',
#   'allen',
#   's',
#   'highly',
#   'popular',
#   'e',
#   'newsletter',
#   'ready',
#   'anything',
#   'offers',
#   'readers',
#   'ways',
#   'immediately',
#   'clear',
#   'head',
#   'creativity',
#   'focus',
#   'attention',
#   'create',
#   'structures',
#   'work',
#   'take',
#   'action',
#   'get',
#   'things',
#   'moving',
#   'wit',
#   'inspiration',
#   'know',
#   'how',
#   'allen',
#   'shows',
#   'readers',
#   'make',
#   'things',
#   'happen',
#   'less',
#   'effort',
#   'stress',
#   'lots',
#   'energy',
#   'creativity',
#   'effectiveness',
#   'ready',
#   'anything',
#   'perfect',
#   'book',
#   'anyone',
#   'wanting',
#   'work',
#   'live',
#   'best'],
#  ['gotta',
#   'get',
#   'new',
#   'marketing',
#   'bring',
#   'blogs',
#   'e',
#   'mail',
#   'youtube',
#   'videos',
#   'myspace',
#   'pages',
#   'google',
#   'adwords',
#   'care',
#   'long',
#   'shiny',
#   'new',
#   'wait',
#   'according',
#   'bestselling',
#   'author',
#   'seth',
#   'godin',
#   'tactics',
#   'like',
#   'toppings',
#   'ice',
#   'cream',
#   'parlor',
#   'start',
#   'ice',
#   'cream',
#   'adding',
#   'cherries',
#   'hot',
#   'fudge',
#   'whipped',
#   'cream',
#   'make',
#   'taste',
#   'great',
#   'start',
#   'bowl',
#   'meatballs',
#   'yuck',
#   'as',
#   'traditional',
#   'marketing',
#   'fades',
#   'away',
#   'new',
#   'tools',
#   'seem',
#   'irresistible',
#   'work',
#   'well',
#   'boring',
#   'brands',
#   'meatballs',
#   'might',
#   'still',
#   'profitable',
#   'attract',
#   'word',
#   'mouth',
#   'cheerios',
#   'ford',
#   'trucks',
#   'barbie',
#   'dolls',
#   'budweiser',
#   'anheuser',
#   'busch',
#   'spends',
#   'million',
#   'online',
#   'network',
#   'called',
#   'budtv',
#   'that',
#   's',
#   'meatball',
#   'sundae',
#   'leads',
#   'new',
#   'bud',
#   'drinkers',
#   'bad',
#   'case',
#   'indigestion',
#   'meatball',
#   'sundae',
#   'definitive',
#   'guide',
#   'fourteen',
#   'trends',
#   'marketer',
#   'afford',
#   'ignore',
#   'explains',
#   'increasing',
#   'power',
#   'stories',
#   'facts',
#   'shorter',
#   'shorter',
#   'attention',
#   'spans',
#   'new',
#   'math',
#   'says',
#   'five',
#   'thousand',
#   'people',
#   'want',
#   'hear',
#   'message',
#   'valuable',
#   'five',
#   'million',
#   'don',
#   't',
#   'winners',
#   'annoying',
#   'start',
#   'ups',
#   'run',
#   'three',
#   'teenagers',
#   'never',
#   'real',
#   'job',
#   'also',
#   'meet',
#   'older',
#   'companies',
#   'adapted',
#   'brilliantly',
#   'blendtec',
#   'thirty',
#   'year',
#   'old',
#   'blender',
#   'maker',
#   'produces',
#   'blend',
#   'videos',
#   'demolish',
#   'golf',
#   'balls',
#   'coke',
#   'cans',
#   'iphones',
#   'much',
#   'more',
#   'hundred',
#   'dollars',
#   'blendtec',
#   'reached',
#   'ten',
#   'million',
#   'eager',
#   'viewers',
#   'youtube',
#   'godin',
#   'pretend',
#   'easy',
#   'get',
#   'products',
#   'marketing',
#   'messages',
#   'internal',
#   'systems',
#   'sync',
#   'he',
#   'll',
#   'convince',
#   'worth',
#   'effort'],
#  ['ranked',
#   'best',
#   'startup',
#   'books',
#   'time',
#   'benzinga',
#   'ranked',
#   'best',
#   'growth',
#   'hacking',
#   'business',
#   'books',
#   'by',
#   'entrepreneur',
#   'com',
#   'best',
#   'sellerin',
#   'startup',
#   'entrepreneurship',
#   'categoriesthis',
#   'compelling',
#   'inspiring',
#   'narrative',
#   'gives',
#   'entrepreneurs',
#   'rare',
#   'behind',
#   'the',
#   'scenes',
#   'look',
#   'inside',
#   'fast',
#   'growing',
#   'startup',
#   'created',
#   'thefirst',
#   'online',
#   'dating',
#   'appand',
#   'grew',
#   'to',
#   'million',
#   'users',
#   'explosive',
#   'growthcombines',
#   'lively',
#   'often',
#   'hilarious',
#   'storytelling',
#   'revealing',
#   'genius',
#   'growth',
#   'tactics',
#   'numerous',
#   'case',
#   'studies',
#   'step',
#   'by',
#   'step',
#   'playbook',
#   'help',
#   'startup',
#   'grow',
#   'massively',
#   'due',
#   'raw',
#   'storytelling',
#   'style',
#   'practical',
#   'lessons',
#   'compelling',
#   'content',
#   'fast',
#   'paced',
#   'read',
#   'explosive',
#   'growthis',
#   'one',
#   'of',
#   'a',
#   'kind',
#   'business',
#   'book',
#   'transcends',
#   'narrow',
#   'entrepreneurial',
#   'audience',
#   'also',
#   'appeal',
#   'readers',
#   'business',
#   'students',
#   'looking',
#   'learn',
#   'startup',
#   'life',
#   'entrepreneurship',
#   'holds',
#   'nothing',
#   'back',
#   'detailingthe',
#   'highest',
#   'highs',
#   'lowest',
#   'lows',
#   'really',
#   'like',
#   'run',
#   'startup',
#   'cliff',
#   'lerner',
#   's',
#   'online',
#   'dating',
#   'startup',
#   'snap',
#   'interactive',
#   'running',
#   'money',
#   'bet',
#   'company',
#   's',
#   'fortunes',
#   'then',
#   'unknown',
#   'platform',
#   'called',
#   'facebook',
#   'app',
#   'suddenly',
#   'began',
#   'acquire',
#   'new',
#   'users',
#   'daily',
#   'free',
#   'soon',
#   'stock',
#   'price',
#   'skyrocketed',
#   'percent',
#   'setting',
#   'extraordinary',
#   'chain',
#   'events',
#   'filled',
#   'sudden',
#   'success',
#   'painful',
#   'lessons',
#   'you',
#   'learn',
#   'to',
#   'ignite',
#   'explosive',
#   'growthby',
#   'creating',
#   'remarkable',
#   'product',
#   'identify',
#   'theonly',
#   'metrics',
#   'matter',
#   'explore',
#   'valuableviral',
#   'growthstrategies',
#   'grow',
#   'rapidly',
#   'execute',
#   'thegenius',
#   'media',
#   'hacksthat',
#   'helped',
#   'us',
#   'acquire',
#   'million',
#   'users',
#   'create',
#   'thriving',
#   'culture',
#   'ofpassionate',
#   'employeesandconstant',
#   'innovationpraise',
#   'a',
#   'must',
#   'read',
#   'founders',
#   'ceos',
#   'want',
#   'achieve',
#   'rapid',
#   'growth',
#   'also',
#   'building',
#   'great',
#   'product',
#   'company',
#   'payal',
#   'kadakia',
#   'founder',
#   'executive',
#   'chairman',
#   'classpass',
#   'explosive',
#   'growth',
#   'without',
#   'question',
#   'one',
#   'useful',
#   'entertaining',
#   'business',
#   'books',
#   'ever',
#   'read',
#   'cliff',
#   'gives',
#   'roadmap',
#   'massively',
#   'grow',
#   'startup',
#   'specific',
#   'tactical',
#   'lessons',
#   'made',
#   'memorable',
#   'engaging',
#   'stories',
#   'book',
#   'must',
#   'read',
#   'david',
#   'perry',
#   'digital',
#   'sales',
#   'business',
#   'development',
#   'expert',
#   'google',
#   'adobe',
#   'amazon',
#   'startup',
#   'advisor',
#   'want',
#   'know',
#   'grow',
#   'startup',
#   'million',
#   'users',
#   'book',
#   'you',
#   'explosive',
#   'growth',
#   'gives',
#   'step',
#   'by',
#   'step',
#   'instructions',
#   'case',
#   'studies',
#   'proven',
#   'tactics',
#   'explode',
#   'growth',
#   'entrepreneur',
#   'magazineby',
#   'syed',
#   'balkhi',
#   'lessons',
#   'startups',
#   'ceos',
#   'growth',
#   'hacking',
#   'marketing',
#   'innovation',
#   'one',
#   'smartest',
#   'founders',
#   'know',
#   'andrew',
#   'weinreich',
#   'inventor',
#   'social',
#   'networking'],
#  ['management',
#   'organized',
#   'body',
#   'knowledge',
#   'this',
#   'book',
#   'peter',
#   'drucker',
#   'swords',
#   'tries',
#   'equip',
#   'manager',
#   'understanding',
#   'thinking',
#   'knowledge',
#   'skills',
#   'today',
#   'sand',
#   'also',
#   'tomorrow',
#   's',
#   'jobs',
#   'management',
#   'classic',
#   'developed',
#   'tested',
#   'thirty',
#   'years',
#   'teaching',
#   'management',
#   'universities',
#   'executive',
#   'programs',
#   'seminars',
#   'author',
#   's',
#   'close',
#   'work',
#   'managers',
#   'consultant',
#   'large',
#   'small',
#   'businesses',
#   'government',
#   'agencies',
#   'hospitals',
#   'schools',
#   'drucker',
#   'discusses',
#   'tools',
#   'techniques',
#   'successful',
#   'management',
#   'practice',
#   'proven',
#   'effective',
#   'makes',
#   'meaningful',
#   'easily',
#   'accessible'],
#  ['find',
#   'following',
#   'explained',
#   'plain',
#   'english',
#   'technical',
#   'jargon',
#   'accounting',
#   'equation',
#   'significant',
#   'read',
#   'prepare',
#   'financial',
#   'statements',
#   'calculate',
#   'interpret',
#   'several',
#   'different',
#   'financial',
#   'ratios',
#   'concepts',
#   'assumptions',
#   'behind',
#   'generally',
#   'accepted',
#   'accounting',
#   'principles',
#   'gaap',
#   'preparing',
#   'journal',
#   'entries',
#   'debits',
#   'credits',
#   'cash',
#   'method',
#   'vs',
#   'accrual',
#   'method',
#   'inventory',
#   'cost',
#   'goods',
#   'sold',
#   'calculate',
#   'depreciation',
#   'amortization',
#   'expenses'],
#  ['donald',
#   'j',
#   'trump',
#   'icon',
#   'definition',
#   'american',
#   'success',
#   'story',
#   'president',
#   'elect',
#   'reality',
#   'television',
#   'star',
#   'developer',
#   'planet',
#   's',
#   'prestigious',
#   'real',
#   'estate',
#   'he',
#   's',
#   'also',
#   'become',
#   'one',
#   'world',
#   's',
#   'wealthiest',
#   'men',
#   'trump',
#   'living',
#   'example',
#   'thinking',
#   'big',
#   'knowing',
#   'back',
#   'opinions',
#   'aggressivelyregardless',
#   'critics',
#   'opponents',
#   'might',
#   'saycan',
#   'help',
#   'maximize',
#   'personal',
#   'professional',
#   'achievements',
#   'first',
#   'political',
#   'campaign',
#   'trump',
#   'defeated',
#   'opponents',
#   'rallying',
#   'voters',
#   'nationwide',
#   'make',
#   'america',
#   'great',
#   'again',
#   'first',
#   'time',
#   'ever',
#   'learn',
#   'trumps',
#   'secrets',
#   'thinking',
#   'big',
#   'kicking',
#   'ass',
#   'learn',
#   'momentum',
#   'big',
#   'mo',
#   'get',
#   'get',
#   'back',
#   'revenge',
#   'get',
#   'and',
#   'sweet',
#   'i',
#   'love',
#   'you',
#   'sign',
#   'this',
#   'contracts',
#   'business',
#   'personal',
#   'life',
#   'important',
#   'real',
#   'life',
#   'stories',
#   'people',
#   'who',
#   've',
#   'applied',
#   'think',
#   'big',
#   'formula',
#   'lives',
#   'these',
#   'strategies',
#   'proven',
#   'attested',
#   'who',
#   've',
#   'learned',
#   'think',
#   'big',
#   'donald',
#   'trump',
#   'found',
#   'success',
#   'lives',
#   'even',
#   'world',
#   'seems',
#   'them',
#   'co',
#   'authored',
#   'bill',
#   'zanker',
#   'entrepreneur',
#   'learned',
#   'tactics',
#   'firsthand',
#   'trump',
#   'think',
#   'big',
#   'kick',
#   'ass',
#   'shows',
#   'bring',
#   'winning',
#   'attitude',
#   'everything',
#   'do'],
#  ['really',
#   'sets',
#   'best',
#   'managers',
#   'rest',
#   'power',
#   'build',
#   'cadre',
#   'employees',
#   'great',
#   'inner',
#   'work',
#   'livesconsistently',
#   'positive',
#   'emotions',
#   'strong',
#   'motivation',
#   'favorable',
#   'perceptions',
#   'organization',
#   'work',
#   'colleagues',
#   'worst',
#   'managers',
#   'undermine',
#   'inner',
#   'work',
#   'life',
#   'often',
#   'unwittingly',
#   'as',
#   'teresa',
#   'amabile',
#   'steven',
#   'kramer',
#   'explain',
#   'progress',
#   'principle',
#   'seemingly',
#   'mundane',
#   'workday',
#   'events',
#   'make',
#   'break',
#   'employees',
#   'inner',
#   'work',
#   'lives',
#   'forward',
#   'momentum',
#   'meaningful',
#   'workprogressthat',
#   'creates',
#   'best',
#   'inner',
#   'work',
#   'lives',
#   'rigorous',
#   'analysis',
#   'nearly',
#   'diary',
#   'entries',
#   'provided',
#   'employees',
#   'companies',
#   'authors',
#   'explain',
#   'managers',
#   'foster',
#   'progress',
#   'enhance',
#   'inner',
#   'work',
#   'life',
#   'every',
#   'day',
#   'the',
#   'book',
#   'shows',
#   'remove',
#   'obstacles',
#   'progress',
#   'including',
#   'meaningless',
#   'tasks',
#   'toxic',
#   'relationships',
#   'also',
#   'explains',
#   'activate',
#   'two',
#   'forces',
#   'enable',
#   'progress',
#   'catalystsevents',
#   'directly',
#   'facilitate',
#   'project',
#   'work',
#   'clear',
#   'goals',
#   'autonomyand',
#   'nourishersinterpersonal',
#   'events',
#   'uplift',
#   'workers',
#   'including',
#   'encouragement',
#   'demonstrations',
#   'respect',
#   'collegiality',
#   'brimming',
#   'honest',
#   'examples',
#   'companies',
#   'studied',
#   'progress',
#   'principle',
#   'equips',
#   'aspiring',
#   'seasoned',
#   'leaders',
#   'alike',
#   'insights',
#   'need',
#   'maximize',
#   'peoples',
#   'performance'],
#  ['clear',
#   'simple',
#   'terms',
#   'leadership',
#   'one',
#   'minute',
#   'manager',
#   'r',
#   'teaches',
#   'managers',
#   'art',
#   'situational',
#   'leadership',
#   'r',
#   'a',
#   'simple',
#   'system',
#   'refutes',
#   'conventional',
#   'management',
#   'mandate',
#   'treating',
#   'employees',
#   'equally',
#   'here',
#   'learn',
#   'tailoring',
#   'management',
#   'styles',
#   'individual',
#   'employees',
#   'important',
#   'knowing',
#   'delegate',
#   'support',
#   'direct',
#   'critical',
#   'identify',
#   'leadership',
#   'style',
#   'suited',
#   'particular',
#   'person',
#   'consistent',
#   'use',
#   'one',
#   'minute',
#   'techniques',
#   'produce',
#   'better',
#   'management',
#   'enhanced',
#   'motivation',
#   'levels',
#   'remarkable',
#   'easy',
#   'to',
#   'follow',
#   'book',
#   'priceless',
#   'guide',
#   'creative',
#   'personalized',
#   'leadership',
#   'elicits',
#   'best',
#   'performance',
#   'staff',
#   'and',
#   'best',
#   'bottom',
#   'line',
#   'business',
#   'if',
#   'management',
#   'motto',
#   'everyone',
#   'treated',
#   'equally',
#   'leadership',
#   'one',
#   'minute',
#   'manager',
#   'show',
#   'style',
#   'hinders',
#   'workplace',
#   'efficiency',
#   'also',
#   'frustrates',
#   'staff',
#   'clear',
#   'simple',
#   'terms',
#   'ken',
#   'blanchard',
#   'co',
#   'author',
#   'enormously',
#   'popular',
#   'one',
#   'minute',
#   'manager',
#   'coupled',
#   'business',
#   'gurus',
#   'patricia',
#   'drea',
#   'zigarmi',
#   'teach',
#   'managers',
#   'art',
#   'situational',
#   'leadership',
#   'learn',
#   'tailoring',
#   'management',
#   'styles',
#   'individual',
#   'employees',
#   'important',
#   'delegate',
#   'support',
#   'direct',
#   'identify',
#   'leadership',
#   'style',
#   'suited',
#   'particular',
#   'person',
#   'consistent',
#   'use',
#   'one',
#   'minute',
#   'techniques',
#   'produce',
#   'better',
#   'management',
#   'enhanced',
#   'motivation',
#   'levels',
#   'remarkable',
#   'easy',
#   'to',
#   'follow',
#   'book',
#   'priceless',
#   'guide',
#   'creative',
#   'personalized',
#   'leadership',
#   'elicits',
#   'best',
#   'performance',
#   'staffand',
#   'best',
#   'bottom',
#   'line',
#   'business'],
#  ['book',
#   'introduction',
#   'robert',
#   'kiyosaki',
#   'one',
#   'i',
#   've',
#   'read',
#   'several',
#   'times',
#   'over',
#   'here',
#   's',
#   'why',
#   'robert',
#   'kiyosaki',
#   'say',
#   'he',
#   's',
#   'never',
#   'involved',
#   'networking',
#   'has',
#   'says',
#   'make',
#   'fortune',
#   'network',
#   'marketing',
#   'there',
#   's',
#   'big',
#   'difference',
#   'remember',
#   'reading',
#   'reviews',
#   'robert',
#   'explains',
#   'reader',
#   'opinion',
#   'networking',
#   'changed',
#   'pg',
#   'when',
#   'early',
#   's',
#   'well',
#   'respected',
#   'financially',
#   'successful',
#   'friend',
#   'told',
#   'robert',
#   'involved',
#   'network',
#   'marketing',
#   'roberts',
#   'past',
#   'disinterest',
#   'networking',
#   'robert',
#   'understand',
#   'man',
#   'completed',
#   'billion',
#   'dollars',
#   'commercial',
#   'real',
#   'estate',
#   'transaction',
#   'would',
#   'involved',
#   'network',
#   'marketing'],
#  ['insider',
#   's',
#   'groundbreaking',
#   'investigation',
#   'global',
#   'elite',
#   's',
#   'efforts',
#   'change',
#   'world',
#   'preserve',
#   'status',
#   'quo',
#   'obscure',
#   'role',
#   'causing',
#   'problems',
#   'later',
#   'seek',
#   'solve',
#   'former',
#   'new',
#   'york',
#   'times',
#   'columnist',
#   'anand',
#   'giridharadas',
#   'takes',
#   'us',
#   'inner',
#   'sanctums',
#   'new',
#   'gilded',
#   'age',
#   'rich',
#   'powerful',
#   'fight',
#   'equality',
#   'justice',
#   'way',
#   'can',
#   'except',
#   'ways',
#   'threaten',
#   'social',
#   'order',
#   'position',
#   'atop',
#   'it',
#   'see',
#   'rebrand',
#   'saviors',
#   'poor',
#   'lavishly',
#   'reward',
#   'thought',
#   'leaders',
#   'redefine',
#   'change',
#   'winner',
#   'friendly',
#   'ways',
#   'constantly',
#   'seek',
#   'good',
#   'never',
#   'less',
#   'harm',
#   'hear',
#   'limousine',
#   'confessions',
#   'celebrated',
#   'foundation',
#   'boss',
#   'witness',
#   'american',
#   'president',
#   'hem',
#   'haw',
#   'plutocratic',
#   'benefactors',
#   'attend',
#   'cruise',
#   'ship',
#   'conference',
#   'entrepreneurs',
#   'celebrate',
#   'self',
#   'interested',
#   'magnanimity',
#   'giridharadas',
#   'asks',
#   'hard',
#   'questions',
#   'why',
#   'example',
#   'gravest',
#   'problems',
#   'solved',
#   'unelected',
#   'upper',
#   'crust',
#   'instead',
#   'public',
#   'institutions',
#   'erodes',
#   'lobbying',
#   'dodging',
#   'taxes',
#   'also',
#   'points',
#   'toward',
#   'answer',
#   'rather',
#   'rely',
#   'scraps',
#   'winners',
#   'must',
#   'take',
#   'grueling',
#   'democratic',
#   'work',
#   'building',
#   'robust',
#   'egalitarian',
#   'institutions',
#   'truly',
#   'changing',
#   'world',
#   'call',
#   'action',
#   'elites',
#   'everyday',
#   'citizens',
#   'alike'],
#  ['bestselling',
#   'author',
#   'one',
#   'worlds',
#   'foremost',
#   'executive',
#   'coaches',
#   'marshall',
#   'goldsmith',
#   'examines',
#   'emotional',
#   'psychological',
#   'triggers',
#   'cause',
#   'us',
#   'react',
#   'behave',
#   'certain',
#   'preset',
#   'often',
#   'inappropriate',
#   'ways',
#   'work',
#   'life',
#   'triggers',
#   'shows',
#   'us',
#   'break',
#   'cycle',
#   'enact',
#   'meaningful',
#   'change',
#   'in',
#   'triggers',
#   'renown',
#   'executive',
#   'coach',
#   'psychologist',
#   'marshall',
#   'goldsmith',
#   'discusses',
#   'emotional',
#   'triggers',
#   'set',
#   'reaction',
#   'behavior',
#   'us',
#   'often',
#   'works',
#   'detriment',
#   'find',
#   'times',
#   'suddenly',
#   'become',
#   'defensive',
#   'enraged',
#   'idle',
#   'comment',
#   'colleague',
#   'temper',
#   'rises',
#   'another',
#   'car',
#   'cuts',
#   'traffic',
#   'reactions',
#   'dont',
#   'occur',
#   'vacuum',
#   'result',
#   'emotional',
#   'psychological',
#   'triggers',
#   'often',
#   'happen',
#   'specific',
#   'settingsat',
#   'meetings',
#   'competitive',
#   'situations',
#   'specific',
#   'person',
#   'rubs',
#   'wrong',
#   'way',
#   'feel',
#   'particular',
#   'pressure',
#   'able',
#   'recognize',
#   'triggers',
#   'understand',
#   'environment',
#   'affects',
#   'behavior',
#   'key',
#   'controlling',
#   'responses',
#   'managing',
#   'others',
#   'work',
#   'life',
#   'make',
#   'mistakechange',
#   'hard',
#   'starting',
#   'point',
#   'willingness',
#   'accept',
#   'help',
#   'desire',
#   'change',
#   'book',
#   'show',
#   'how',
#   'over',
#   'course',
#   'book',
#   'marshall',
#   'explores',
#   'power',
#   'active',
#   'questions',
#   'get',
#   'us',
#   'take',
#   'responsibility',
#   'actionsand',
#   'failure',
#   'act',
#   'questions',
#   'best',
#   'make',
#   'progress',
#   'toward',
#   'goal',
#   'work',
#   'hard',
#   'fully',
#   'engaged',
#   'discusses',
#   'importance',
#   'structure',
#   'effecting',
#   'permanent',
#   'change',
#   'because',
#   'points',
#   'out',
#   'change',
#   'hard',
#   'without',
#   'structure',
#   'keep',
#   'us',
#   'track',
#   'inevitably',
#   'relapse',
#   'fall',
#   'back',
#   'filled',
#   'illuminating',
#   'stories',
#   'marshalls',
#   'work',
#   'accomplished',
#   'executives',
#   'leaders',
#   'america',
#   'triggers',
#   'shows',
#   'readers',
#   'achieve',
#   'meaningful',
#   'sustained',
#   'change',
#   'allow',
#   'us',
#   'open',
#   'imaginations',
#   'escape',
#   'rigidity',
#   'binary',
#   'thinking'],
#  ['guide',
#   'creating',
#   'engaging',
#   'web',
#   'content',
#   'building',
#   'loyal',
#   'following',
#   'revised',
#   'updated',
#   'blogs',
#   'youtube',
#   'facebook',
#   'twitter',
#   'google',
#   'platforms',
#   'giving',
#   'everyone',
#   'voice',
#   'including',
#   'organizations',
#   'customers',
#   'create',
#   'stories',
#   'videos',
#   'blog',
#   'posts',
#   'cultivate',
#   'fans',
#   'arouse',
#   'passion',
#   'products',
#   'services',
#   'ignite',
#   'business',
#   'content',
#   'rules',
#   'equips',
#   'online',
#   'success',
#   'one',
#   'stop',
#   'source',
#   'art',
#   'science',
#   'developing',
#   'content',
#   'people',
#   'care',
#   'about',
#   'coverage',
#   'interwoven',
#   'case',
#   'studies',
#   'companies',
#   'successfully',
#   'spreading',
#   'ideas',
#   'online',
#   'and',
#   'using',
#   'establish',
#   'credibility',
#   'build',
#   'loyal',
#   'customer',
#   'base',
#   'find',
#   'authentic',
#   'voice',
#   'craft',
#   'bold',
#   'content',
#   'resonate',
#   'prospects',
#   'buyers',
#   'encourage',
#   'share',
#   'others',
#   'leverage',
#   'social',
#   'media',
#   'social',
#   'tools',
#   'get',
#   'content',
#   'ideas',
#   'distributed',
#   'widely',
#   'possible',
#   'understand',
#   'generating',
#   'content',
#   'getting',
#   'meat',
#   'message',
#   'practical',
#   'commonsense',
#   'language',
#   'defining',
#   'goals',
#   'content',
#   'strategy',
#   'write',
#   'way',
#   'powerfully',
#   'communicates',
#   'service',
#   'product',
#   'message',
#   'across',
#   'various',
#   'web',
#   'mediums',
#   'boost',
#   'online',
#   'presence',
#   'engage',
#   'customers',
#   'prospects',
#   'like',
#   'never',
#   'content',
#   'rules'],
#  ['author',
#   'q',
#   'a',
#   'tim',
#   'harford',
#   'economic',
#   'missionary',
#   'something',
#   'love',
#   'do',
#   'began',
#   'something',
#   'love',
#   'do',
#   'and',
#   'think',
#   'starting',
#   'get',
#   'sense',
#   'mission',
#   'people',
#   'use',
#   'economics',
#   'use',
#   'statistics',
#   'numbers',
#   'get',
#   'truth',
#   'real',
#   'appetite',
#   'so',
#   'bbc',
#   'thing',
#   'say',
#   'theres',
#   'almost',
#   'public',
#   'service',
#   'mission',
#   'fulfilled',
#   'educating',
#   'people',
#   'economics',
#   'wrote',
#   'undercover',
#   'economist',
#   'pure',
#   'enthusiasm',
#   'subject',
#   'book',
#   'full',
#   'stuff',
#   'wanted',
#   'say',
#   'always',
#   'thing',
#   'books',
#   'always',
#   'fun',
#   'write',
#   'think',
#   'people',
#   'days',
#   'generally',
#   'economically',
#   'literate',
#   'people',
#   'aware',
#   'economics',
#   'various',
#   'reasons',
#   'problems',
#   'economy',
#   'there',
#   'always',
#   'interest',
#   'economics',
#   'going',
#   'wrong',
#   'border',
#   'line',
#   'new',
#   'book',
#   'economics',
#   'sociology',
#   'dont',
#   'draw',
#   'border',
#   'line',
#   'particularly',
#   'new',
#   'book',
#   'undercover',
#   'economist',
#   'basically',
#   'cool',
#   'economics',
#   'could',
#   'think',
#   'logic',
#   'life',
#   'investigating',
#   'particular',
#   'part',
#   'economics',
#   'references',
#   'logic',
#   'life',
#   'academic',
#   'economics',
#   'papers',
#   'related',
#   'and',
#   'hopefully',
#   'made',
#   'fun',
#   'new',
#   'book',
#   'adapt',
#   'different',
#   'started',
#   'asking',
#   'wrong',
#   'world',
#   'needs',
#   'fixing',
#   'work',
#   'and',
#   'economics',
#   'tell',
#   'us',
#   'something',
#   'which',
#   'can',
#   'used',
#   'it',
#   'economics',
#   'tool',
#   'need',
#   'if',
#   'need',
#   'turn',
#   'sociology',
#   'engineering',
#   'biology',
#   'psychology',
#   'i',
#   'have',
#   'fact',
#   'turned',
#   'book',
#   'thats',
#   'need',
#   'thats',
#   'gone',
#   'written',
#   'book',
#   'different',
#   'way',
#   'started',
#   'problem',
#   'tried',
#   'figure',
#   'solve',
#   'it',
#   'specific',
# ...
#   'enough',
#   'insure',
#   'success',
#   'while',
#   'book',
#   'read',
#   'millions',
#   'career',
#   'sales',
#   'people',
#   'written',
#   'consider',
#   'sales',
#   'people',
#   'want',
#   'achieve',
#   'success',
#   'life',
#   'book',
#   'get',
#   'done',
#   'life',
#   'selling',
#   'show',
#   'reader',
#   'success',
#   'impossible',
#   'without',
#   'understanding',
#   'concepts',
#   'selling',
#   'introduced',
#   'incredibly',
#   'simple',
#   'ways',
#   'sell',
#   'product',
#   'idea',
#   'anyone',
#   'time',
#   'learn',
#   'get',
#   'others',
#   'buy',
#   'agree',
#   'ideas',
#   'get',
#   'behind',
#   'help',
#   'you',
#   'you',
#   'learn',
#   'strategies',
#   'insure',
#   'successful',
#   'life',
#   'show',
#   'exactly',
#   'get',
#   'want',
#   'go',
#   'know',
#   'eliminate',
#   'confrontation',
#   'end',
#   'disagreements',
#   'words',
#   'attitude',
#   'shown',
#   'greats',
#   'persuasive',
#   'reason',
#   'people',
#   'like',
#   'sales',
#   'predict',
#   'others',
#   'say',
#   'build',
#   'trust',
#   'separate',
#   'average',
#   'prospect',
#   'gets',
#   'weird',
#   'around',
#   'money',
#   'hard',
#   'sell',
#   'without',
#   'using',
#   'pressure',
#   'two',
#   'single',
#   'important',
#   'steps',
#   'success',
#   'sales',
#   'much',
#   'much',
#   'more',
#   'this',
#   'fresh',
#   'look',
#   'selling',
#   'use',
#   'forgotten',
#   'art',
#   'respectful',
#   'ethical',
#   'way',
#   'get',
#   'everything',
#   'want',
#   'life'],
#  ['deming',
#   'offers',
#   'theory',
#   'management',
#   'based',
#   'famous',
#   'points',
#   'management',
#   'long',
#   'term',
#   'commitment',
#   'new',
#   'learning',
#   'new',
#   'philosophy',
#   'required',
#   'management',
#   'seeks',
#   'transformation',
#   'timid',
#   'fainthearted',
#   'people',
#   'expect',
#   'quick',
#   'results',
#   'doomed',
#   'disappointment',
#   'according',
#   'w',
#   'edwards',
#   'deming',
#   'american',
#   'companies',
#   'require',
#   'nothing',
#   'less',
#   'transformation',
#   'management',
#   'style',
#   'governmental',
#   'relations',
#   'industry',
#   'crisis',
#   'originally',
#   'published',
#   'deming',
#   'offers',
#   'theory',
#   'management',
#   'based',
#   'famous',
#   'points',
#   'management',
#   'management',
#   's',
#   'failure',
#   'plan',
#   'future',
#   'claims',
#   'brings',
#   'loss',
#   'market',
#   'brings',
#   'loss',
#   'jobs',
#   'management',
#   'must',
#   'judged',
#   'quarterly',
#   'dividend',
#   'innovative',
#   'plans',
#   'stay',
#   'business',
#   'protect',
#   'investment',
#   'ensure',
#   'future',
#   'dividends',
#   'provide',
#   'jobs',
#   'improved',
#   'product',
#   'service',
#   'simple',
#   'direct',
#   'language',
#   'explains',
#   'principles',
#   'management',
#   'transformation',
#   'apply',
#   'them',
#   'previously',
#   'published',
#   'mit',
#   'caes'],
#  ['favor',
#   'next',
#   'time',
#   'instead',
#   'lunch',
#   'break',
#   'go',
#   'bookstore',
#   'find',
#   'book',
#   'simply',
#   'go',
#   'chapter',
#   'end',
#   'chapters',
#   'list',
#   'bullet',
#   'points',
#   'summarize',
#   'chapter',
#   's',
#   'ideas',
#   'there',
#   'chapters',
#   'every',
#   'chapter',
#   'bullet',
#   'point',
#   'list',
#   'ever',
#   'chapter',
#   'applicable',
#   'e',
#   'g',
#   'negotiation',
#   'methods',
#   'americans',
#   'can',
#   't',
#   'imagine',
#   'taking',
#   'minutes',
#   'finish',
#   'but',
#   'real',
#   'time',
#   'desire',
#   'read'],
#  ['wondering',
#   'next',
#   'killer',
#   'app',
#   'be',
#   'want',
#   'know',
#   'maintain',
#   'add',
#   'value',
#   'rapidly',
#   'changing',
#   'times',
#   'wondering',
#   'word',
#   'love',
#   'even',
#   'used',
#   'context',
#   'business',
#   'instead',
#   'wondering',
#   'read',
#   'book',
#   'find',
#   'become',
#   'lovecata',
#   'nice',
#   'smart',
#   'person',
#   'succeeds',
#   'business',
#   'life',
#   'how',
#   'become',
#   'lovecat',
#   'sharing',
#   'intangibles',
#   'mean',
#   'knowledge',
#   'everything',
#   'comes',
#   'books',
#   'ill',
#   'encourage',
#   'devour',
#   'your',
#   'network',
#   'collection',
#   'friends',
#   'contacts',
#   'have',
#   'ill',
#   'teach',
#   'grow',
#   'nurture',
#   'your',
#   'compassion',
#   'human',
#   'warmth',
#   'already',
#   'possessin',
#   'pages',
#   'ill',
#   'convince',
#   'show',
#   'freely',
#   'office',
#   'what',
#   'happens',
#   'this',
#   'become',
#   'rich',
#   'source',
#   'information',
#   'around',
#   'you',
#   'seen',
#   'person',
#   'valuable',
#   'insight',
#   'perceived',
#   'generous',
#   'fault',
#   'producing',
#   'surprise',
#   'delight',
#   'double',
#   'business',
#   'intelligence',
#   'one',
#   'year',
#   'triple',
#   'network',
#   'personal',
#   'relationships',
#   'two',
#   'years',
#   'quadruple',
#   'number',
#   'colleagues',
#   'life',
#   'love',
#   'like',
#   'family',
#   'in',
#   'short',
#   'become',
#   'one',
#   'amazing',
#   'outstanding',
#   'people',
#   'everyone',
#   'turns',
#   'leads',
#   'rather',
#   'follows',
#   'never',
#   'runs',
#   'ideas',
#   'contacts',
#   'friendship',
#   'heres',
#   'real',
#   'scoop',
#   'nice',
#   'guys',
#   'dont',
#   'finish',
#   'last',
#   'rule',
#   'from',
#   'hardcover',
#   'edition'],
#  ['days',
#   'work',
#   'love',
#   'much',
#   'finding',
#   'new',
#   'job',
#   'learning',
#   'really',
#   'called',
#   'be',
#   'according',
#   'author',
#   'failing',
#   'make',
#   'fundamental',
#   'discovery',
#   'many',
#   'people',
#   'find',
#   'jobs',
#   'hate',
#   'now',
#   'thousands',
#   'upon',
#   'thousands',
#   'finding',
#   'work',
#   'love',
#   'thanks',
#   'practical',
#   'advice',
#   'leading',
#   'career',
#   'counselor',
#   'miller',
#   'conversational',
#   'creative',
#   'miller',
#   'helps',
#   'readers',
#   'see',
#   'clear',
#   'patterns',
#   'form',
#   'make',
#   'successful',
#   'career',
#   'job',
#   'decisions',
#   'understanding',
#   'god',
#   'given',
#   'skills',
#   'abilities',
#   'personality',
#   'traits',
#   'values',
#   'dreams',
#   'passions',
#   'days',
#   'work',
#   'love',
#   'provides',
#   'step',
#   'by',
#   'step',
#   'process',
#   'creating',
#   'life',
#   'plan',
#   'translating',
#   'plan',
#   'meaningful',
#   'fulfilling',
#   'daily',
#   'work'],
#  ['much',
#   'advice',
#   'weve',
#   'told',
#   'achievement',
#   'logical',
#   'earnestand',
#   'downright',
#   'wrong',
#   'barking',
#   'wrong',
#   'tree',
#   'eric',
#   'barker',
#   'reveals',
#   'extraordinary',
#   'science',
#   'behind',
#   'actually',
#   'determines',
#   'success',
#   'importantly',
#   'anyone',
#   'achieve',
#   'it',
#   'youll',
#   'learn',
#   'valedictorians',
#   'rarely',
#   'become',
#   'millionaires',
#   'biggest',
#   'weakness',
#   'might',
#   'actually',
#   'greatest',
#   'strength',
#   'whether',
#   'nice',
#   'guys',
#   'finish',
#   'last',
#   'best',
#   'lessons',
#   'cooperation',
#   'come',
#   'gang',
#   'members',
#   'pirates',
#   'serial',
#   'killers',
#   'trying',
#   'increase',
#   'confidence',
#   'fails',
#   'buddhist',
#   'philosophy',
#   'holds',
#   'superior',
#   'solution',
#   'secret',
#   'ingredient',
#   'grit',
#   'navy',
#   'seals',
#   'disaster',
#   'survivors',
#   'leverage',
#   'keep',
#   'going',
#   'find',
#   'work',
#   'life',
#   'balance',
#   'using',
#   'strategy',
#   'genghis',
#   'khan',
#   'errors',
#   'albert',
#   'einstein',
#   'little',
#   'lesson',
#   'spider',
#   'manby',
#   'looking',
#   'separates',
#   'extremely',
#   'successful',
#   'rest',
#   'us',
#   'learn',
#   'like',
#   'themand',
#   'find',
#   'cases',
#   'good',
#   'arent',
#   'barking',
#   'wrong',
#   'tree',
#   'draws',
#   'startling',
#   'statistics',
#   'surprising',
#   'anecdotes',
#   'help',
#   'understand',
#   'works',
#   'doesnt',
#   'stop',
#   'guessing',
#   'success',
#   'start',
#   'living',
#   'life',
#   'want'],
#  ['good',
#   'are',
#   'good',
#   'want',
#   'handbook',
#   'succeed',
#   'world',
#   'pocket',
#   'bible',
#   'talented',
#   'timid',
#   'alike',
#   'help',
#   'make',
#   'unthinkable',
#   'thinkable',
#   'impossible',
#   'possible',
#   'the',
#   'worlds',
#   'top',
#   'advertising',
#   'guru',
#   'paul',
#   'arden',
#   'offers',
#   'wisdom',
#   'issues',
#   'diverse',
#   'problem',
#   'solving',
#   'responding',
#   'brief',
#   'communicating',
#   'playing',
#   'cards',
#   'right',
#   'making',
#   'mistakes',
#   'creativity',
#   'endeavors',
#   'applied',
#   'aspects',
#   'modern',
#   'life',
#   'this',
#   'uplifting',
#   'humorous',
#   'little',
#   'book',
#   'provides',
#   'unique',
#   'insight',
#   'world',
#   'advertising',
#   'quirky',
#   'compilation',
#   'quotes',
#   'facts',
#   'pictures',
#   'wit',
#   'wisdom',
#   'packed',
#   'easy',
#   'to',
#   'digest',
#   'bite',
#   'sized',
#   'spreads',
#   'want',
#   'succeed',
#   'life',
#   'business',
#   'book',
#   'must'],
#  ['steve',
#   'jobs',
#   'simplicity',
#   'religion',
#   'also',
#   'weapon',
#   'simplicity',
#   'isnt',
#   'design',
#   'principle',
#   'appleits',
#   'value',
#   'permeates',
#   'every',
#   'level',
#   'organization',
#   'obsession',
#   'simplicity',
#   'separates',
#   'apple',
#   'technology',
#   'companies',
#   'helped',
#   'apple',
#   'recover',
#   'near',
#   'death',
#   'become',
#   'valuable',
#   'company',
#   'earth',
#   'thanks',
#   'steve',
#   'jobss',
#   'uncompromising',
#   'ways',
#   'see',
#   'simplicity',
#   'everything',
#   'apple',
#   'does',
#   'way',
#   'structured',
#   'way',
#   'innovates',
#   'way',
#   'speaks',
#   'customers',
#   'its',
#   'crushing',
#   'forces',
#   'complexity',
#   'company',
#   'remains',
#   'stellar',
#   'trajectory',
#   'as',
#   'ad',
#   'agency',
#   'creative',
#   'director',
#   'ken',
#   'segall',
#   'played',
#   'key',
#   'role',
#   'apples',
#   'resurrection',
#   'helping',
#   'create',
#   'critical',
#   'marketing',
#   'campaigns',
#   'think',
#   'different',
#   'naming',
#   'imac',
#   'also',
#   'laid',
#   'foundation',
#   'naming',
#   'waves',
#   'i',
#   'products',
#   'come',
#   'segall',
#   'unique',
#   'perspective',
#   'given',
#   'years',
#   'experience',
#   'creating',
#   'campaigns',
#   'iconic',
#   'tech',
#   'companies',
#   'including',
#   'ibm',
#   'intel',
#   'dell',
#   'stark',
#   'contrast',
#   'apples',
#   'ways',
#   'made',
#   'segall',
#   'appreciate',
#   'power',
#   'simplicityand',
#   'inspired',
#   'help',
#   'others',
#   'benefit',
#   'it',
#   'in',
#   'insanely',
#   'simple',
#   'youll',
#   'fly',
#   'wall',
#   'inside',
#   'conference',
#   'room',
#   'steve',
#   'jobs',
#   'receiving',
#   'end',
#   'midnight',
#   'phone',
#   'calls',
#   'youll',
#   'understand',
#   'obsession',
#   'simplicity',
#   'helped',
#   'apple',
#   'perform',
#   'better',
#   'faster',
#   'sometimes',
#   'saving',
#   'millions',
#   'process',
#   'youll',
#   'also',
#   'learn',
#   'example',
#   'to',
#   'think',
#   'minimal',
#   'distilling',
#   'choices',
#   'minimum',
#   'brings',
#   'clarity',
#   'company',
#   'customersas',
#   'jobs',
#   'proved',
#   'replaced',
#   'twenty',
#   'product',
#   'models',
#   'lineup',
#   'four',
#   'think',
#   'small',
#   'swearing',
#   'allegiance',
#   'concept',
#   'small',
#   'groups',
#   'smart',
#   'people',
#   'raises',
#   'morale',
#   'productivity',
#   'think',
#   'motion',
#   'keeping',
#   'project',
#   'teams',
#   'constant',
#   'motion',
#   'focuses',
#   'creative',
#   'thinking',
#   'well',
#   'defined',
#   'goals',
#   'minimizes',
#   'distractions',
#   'think',
#   'iconic',
#   'using',
#   'simple',
#   'powerful',
#   'image',
#   'symbolize',
#   'benefit',
#   'product',
#   'idea',
#   'creates',
#   'deeper',
#   'impression',
#   'minds',
#   'customers',
#   'think',
#   'war',
#   'giving',
#   'unfair',
#   'advantageusing',
#   'every',
#   'weapon',
#   'disposalis',
#   'best',
#   'way',
#   'ensure',
#   'ideas',
#   'survive',
#   'unscathed',
#   'segall',
#   'brings',
#   'apples',
#   'quest',
#   'simplicity',
#   'life',
#   'using',
#   'fascinating',
#   'and',
#   'previously',
#   'untold',
#   'stories',
#   'behind',
#   'scenes',
#   'insight',
#   'wit',
#   'youll',
#   'discover',
#   'companies',
#   'leverage',
#   'power',
#   'stand',
#   'competitorsand',
#   'individuals',
#   'master',
#   'become',
#   'critical',
#   'assets',
#   'organizations'],
#  ['updated',
#   'edition',
#   'critically',
#   'acclaimed',
#   'bestselling',
#   'book',
#   'microsoft',
#   'project',
#   'veteran',
#   'scott',
#   'berkun',
#   'offers',
#   'collection',
#   'essays',
#   'field',
#   'tested',
#   'philosophies',
#   'strategies',
#   'defining',
#   'leading',
#   'managing',
#   'projects',
#   'essay',
#   'distills',
#   'complex',
#   'concepts',
#   'challenges',
#   'practical',
#   'nuggets',
#   'useful',
#   'advice',
#   'new',
#   'edition',
#   'adds',
#   'value',
#   'leaders',
#   'managers',
#   'projects',
#   'everywhere',
#   'based',
#   'nine',
#   'years',
#   'experience',
#   'program',
#   'manager',
#   'internet',
#   'explorer',
#   'lead',
#   'program',
#   'manager',
#   'windows',
#   'msn',
#   'berkun',
#   'explains',
#   'technical',
#   'non',
#   'technical',
#   'readers',
#   'alike',
#   'takes',
#   'get',
#   'large',
#   'software',
#   'web',
#   'development',
#   'project',
#   'making',
#   'things',
#   'happen',
#   'cite',
#   'specific',
#   'methods',
#   'focuses',
#   'philosophy',
#   'strategy',
#   'unlike',
#   'project',
#   'management',
#   'books',
#   'berkun',
#   'offers',
#   'personal',
#   'essays',
#   'comfortable',
#   'style',
#   'easy',
#   'tone',
#   'emulate',
#   'relationship',
#   'wise',
#   'project',
#   'manager',
#   'gives',
#   'good',
#   'entertaining',
#   'passionate',
#   'advice',
#   'ask',
#   'topics',
#   'new',
#   'edition',
#   'include',
#   'how',
#   'make',
#   'things',
#   'happenmaking',
#   'good',
#   'decisionsspecifications',
#   'requirementsideas',
#   'themhow',
#   'annoy',
#   'peopleleadership',
#   'trustthe',
#   'truth',
#   'making',
#   'dateswhat',
#   'things',
#   'go',
#   'wrongcomplete',
#   'new',
#   'forward',
#   'author',
#   'discussion',
#   'guide',
#   'forming',
#   'reading',
#   'groups',
#   'teams',
#   'making',
#   'things',
#   'happen',
#   'offers',
#   'in',
#   'depth',
#   'exercises',
#   'help',
#   'apply',
#   'lessons',
#   'book',
#   'job',
#   'inspiring',
#   'funny',
#   'honest',
#   'compelling',
#   'definitely',
#   'one',
#   'book',
#   'team',
#   'need',
#   'within',
#   'arm',
#   's',
#   'reach',
#   'throughout',
#   'life',
#   'project',
#   'coming',
#   'rare',
#   'perspective',
#   'someone',
#   'fought',
#   'difficult',
#   'battles',
#   'microsoft',
#   's',
#   'biggest',
#   'projects',
#   'taught',
#   'project',
#   'design',
#   'management',
#   'mste',
#   'microsoft',
#   's',
#   'internal',
#   'best',
#   'practices',
#   'group',
#   'valuable',
#   'advice',
#   'indeed',
#   'serve',
#   'well',
#   'current',
#   'work',
#   'future',
#   'projects',
#   'come'],
#  ['brilliant',
#   'distillations',
#   'strategies',
#   'warand',
#   'subtle',
#   'social',
#   'game',
#   'everyday',
#   'lifeby',
#   'bestselling',
#   'author',
#   'laws',
#   'power',
#   'masteryrobert',
#   'greenes',
#   'groundbreaking',
#   'guides',
#   'laws',
#   'power',
#   'art',
#   'seduction',
#   'latest',
#   'book',
#   'mastery',
#   'espouse',
#   'profound',
#   'timeless',
#   'lessons',
#   'events',
#   'history',
#   'help',
#   'readers',
#   'vanquish',
#   'enemy',
#   'ensnare',
#   'unsuspecting',
#   'victim',
#   'become',
#   'greatest',
#   'field',
#   'strategies',
#   'war',
#   'greene',
#   'crafted',
#   'important',
#   'addition',
#   'ruthless',
#   'unique',
#   'series',
#   'spanning',
#   'world',
#   'civilizations',
#   'synthesizing',
#   'dozens',
#   'political',
#   'philosophical',
#   'religious',
#   'texts',
#   'thousands',
#   'years',
#   'violent',
#   'conflict',
#   'strategies',
#   'war',
#   'comprehensive',
#   'guide',
#   'subtle',
#   'social',
#   'game',
#   'everyday',
#   'life',
#   'informed',
#   'ingenious',
#   'effective',
#   'military',
#   'principles',
#   'war',
#   'structured',
#   'greenes',
#   'trademark',
#   'style',
#   'strategies',
#   'war',
#   'i',
#   'ching',
#   'conflict',
#   'contemporary',
#   'companion',
#   'sun',
#   'tzus',
#   'art',
#   'war',
#   'abundantly',
#   'illustrated',
#   'examples',
#   'history',
#   'including',
#   'folly',
#   'genius',
#   'everyone',
#   'napoleon',
#   'margaret',
#   'thatcher',
#   'shaka',
#   'zulu',
#   'lord',
#   'nelson',
#   'hannibal',
#   'ulysses',
#   's',
#   'grant',
#   'well',
#   'movie',
#   'moguls',
#   'samurai',
#   'swordsmen',
#   'diplomats',
#   'thirty',
#   'three',
#   'chapters',
#   'outlines',
#   'strategy',
#   'help',
#   'win',
#   'lifes',
#   'wars',
#   'learn',
#   'offensive',
#   'strategies',
#   'require',
#   'maintain',
#   'initiative',
#   'negotiate',
#   'position',
#   'strength',
#   'defensive',
#   'strategies',
#   'designed',
#   'help',
#   'respond',
#   'dangerous',
#   'situations',
#   'avoid',
#   'unwinnable',
#   'wars',
#   'great',
#   'warriors',
#   'battlefields',
#   'drawing',
#   'rooms',
#   'alike',
#   'demonstrate',
#   'prudence',
#   'agility',
#   'balance',
#   'calm',
#   'keen',
#   'understanding',
#   'rational',
#   'resourceful',
#   'intuitive',
#   'always',
#   'defeat',
#   'panicked',
#   'uncreative',
#   'stupid',
#   'indispensable',
#   'book',
#   'strategies',
#   'war',
#   'provides',
#   'psychological',
#   'ammunition',
#   'need',
#   'overcome',
#   'patterns',
#   'failure',
#   'forever',
#   'gain',
#   'upper',
#   'hand'],
#  ...]

# %%
# !pip install Word2Vec
# Out:
# Collecting Word2Vec
#   Using cached word2vec-0.11.1.tar.gz (42 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from Word2Vec) (1.20.3)
# Requirement already satisfied: joblib in c:\users\user\desktop\.ipynb_checkpoints\lib\site-packages (from Word2Vec) (1.1.0)
# Building wheels for collected packages: Word2Vec
#   Building wheel for Word2Vec (PEP 517): started
#   Building wheel for Word2Vec (PEP 517): finished with status 'error'
# Failed to build Word2Vec
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\user\Desktop\.ipynb_checkpoints\python.exe' 'C:\Users\user\Desktop\.ipynb_checkpoints\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\user\AppData\Local\Temp\tmpvj11p6lo'
#        cwd: C:\Users\user\AppData\Local\Temp\pip-install-bjxvotgn\word2vec_ad65ebc187654e47a7475a9b7b4ff8d4
#   Complete output (47 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib
#   creating build\lib\word2vec
#   copying word2vec\io.py -> build\lib\word2vec
#   copying word2vec\scripts_interface.py -> build\lib\word2vec
#   copying word2vec\utils.py -> build\lib\word2vec
#   copying word2vec\wordclusters.py -> build\lib\word2vec
#   copying word2vec\wordvectors.py -> build\lib\word2vec
#   copying word2vec\_generated_version.py -> build\lib\word2vec
#   copying word2vec\__init__.py -> build\lib\word2vec
#   creating build\lib\word2vec\tests
#   copying word2vec\tests\test_core.py -> build\lib\word2vec\tests
#   copying word2vec\tests\test_import.py -> build\lib\word2vec\tests
#   copying word2vec\tests\test_scripts_present.py -> build\lib\word2vec\tests
#   copying word2vec\tests\__init__.py -> build\lib\word2vec\tests
#   running egg_info
#   writing word2vec.egg-info\PKG-INFO
#   writing dependency_links to word2vec.egg-info\dependency_links.txt
#   writing requirements to word2vec.egg-info\requires.txt
#   writing top-level names to word2vec.egg-info\top_level.txt
#   reading manifest file 'word2vec.egg-info\SOURCES.txt'
#   adding license file 'LICENSE.txt'
#   writing manifest file 'word2vec.egg-info\SOURCES.txt'
#   creating build\lib\word2vec\includes
#   copying word2vec\includes\Makefile -> build\lib\word2vec\includes
#   copying word2vec\includes\compute-accuracy.c -> build\lib\word2vec\includes
#   copying word2vec\includes\distance.c -> build\lib\word2vec\includes
#   copying word2vec\includes\word-analogy.c -> build\lib\word2vec\includes
#   copying word2vec\includes\word2phrase.c -> build\lib\word2vec\includes
#   copying word2vec\includes\word2vec-sentence2vec.c -> build\lib\word2vec\includes
#   copying word2vec\includes\word2vec.c -> build\lib\word2vec\includes
#   creating build\lib\word2vec\includes\win32
#   copying word2vec\includes\win32\Makefile -> build\lib\word2vec\includes\win32
#   copying word2vec\includes\win32\compute-accuracy.c -> build\lib\word2vec\includes\win32
#   copying word2vec\includes\win32\distance.c -> build\lib\word2vec\includes\win32
#   copying word2vec\includes\win32\win32-port.h -> build\lib\word2vec\includes\win32
#   copying word2vec\includes\win32\word-analogy.c -> build\lib\word2vec\includes\win32
#   copying word2vec\includes\win32\word2phrase.c -> build\lib\word2vec\includes\win32
#   copying word2vec\includes\win32\word2vec.c -> build\lib\word2vec\includes\win32
#   installing to build\bdist.win-amd64\wheel
#   running install
#   Running custom Install command
#   Compiling: gcc C:\Users\user\AppData\Local\Temp\pip-install-bjxvotgn\word2vec_ad65ebc187654e47a7475a9b7b4ff8d4\word2vec\includes\win32/word2vec.c -o Scripts\word2vec.exe -O2 -Wall -funroll-loops
#   error: [WinError 2] 지정된 파일을 찾을 수 없습니다
#   ----------------------------------------
#   ERROR: Failed building wheel for Word2Vec
# ERROR: Could not build wheels for Word2Vec which use PEP 517 and cannot be installed directly

# %%
# 벡터화시킬 단어 수 = 300
word2vec_model = Word2Vec(size = 300, window = 5, min_count = 2, workers = 1)
word2vec_model.build_vocab(corpus)

# %%
word2vec_model.wv.vectors_lockf=np.ones(len(word2vec_model.wv), dtype=np.float32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14276/401034157.py in <module>
# ----> 1 word2vec_model.vectors_lockf=np.ones(len(word2vec_model), dtype=np.float32)
#
# TypeError: object of type 'Word2Vec' has no len()

# %%
# gensim 3.x -> Word2Vec.intersect_word2vec_format
# gensim 4.x -> Word2Vec.wv.intersect_word2vec_format
word2vec_model.wv.intersect_word2vec_format('./dataset/GoogleNews-vectors-negative300.bin.gz', lockf = 1.0, binary = True)

# %%
word2vec_model.train(corpus, total_examples = word2vec_model.corpus_count, epochs = 15)

# %%
# 단어 벡터 평균
def get_doc_vectors(doc_list):
    doc_embedding_list = []
    
    for line in doc_list:
        doc2vec = None
        count = 0
        
        for word in line.split():
            if word in word2vec_model.wv.index_to_key:
                count += 1
                # 문서에 있는 모든 단어들의 벡터를 연산
                if doc2vec in None:
                    # doc2vec = word2vec_model[word]
                    doc2vec = word2vec_model.wv[word]
                else:
                    doc2vec = doc2vec + word2vec_model.wv[word]
        
        # 단어 벡터를 모두 연산한 벡터의 값을 문서 길이로 나누기
        if doc2vec is not None:
            doc2vec = doc2vec / count
            doc_embedding_list.append(doc2vec)
            
    return doc_embedding_list

# %%
doc_embedding_list = get_doc_vectors(df['cleaned'])
print(f'문서 벡터 수: {len(doc_embedding_list)}')

# %%
cosine_similarities = cosine_similarity(doc_embedding_list, doc_embedding_list)
print(cosine_similarities.shape)

# %%
def recommendations(title):
    columns = df[['title', 'image_link']]
    
    indices = pd.Series(df.index, index = df['title']).drop_duplicates()
    idx = indices[title]
    
    # 입력한 데이터와 유사한 데이터 추천
    sim_scores = list(enumerate(cosine_similarities[idx]))
    sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)
    sim_scores = sim_scores[1:6] # 상위 5개
    
    _indices = [i[0] for i in sim_scores]
    
    recommend = columns.iloc[_indices].reset_index(drop = True)
    
    fig = plt.figure(figsize = (20, 30))
    
    for index, row in recommend.iterrows():
        response = requests.get(row['image_link'])
        img = Image.open(BytesIO(response.content))
        fig.add_subplot(1, 5, index + 1)
        plt.imshow(img)
        plt.title(row['title'])

# %%
recommendations('The Hunger Games')
